# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Importing Iris Data Set

# %%
df=pd.read_csv('Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.drop(['Id'],axis=1)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Reading Data Set

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data=df.drop_duplicates(subset="Species")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 50    51            7.0           3.2            4.7           1.4
# 100  101            6.3           3.3            6.0           2.5
#
#              Species
# 0        Iris-setosa
# 50   Iris-versicolor
# 100   Iris-virginica

# %%
data=df.drop_duplicates(subset="Species")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 50    51            7.0           3.2            4.7           1.4
# 100  101            6.3           3.3            6.0           2.5
#
#              Species
# 0        Iris-setosa
# 50   Iris-versicolor
# 100   Iris-virginica

# %%
df.value_counts("SepalLengthCm")
# Out:
# SepalLengthCm
# 5.0    10
# 6.3     9
# 5.1     9
# 5.7     8
# 6.7     8
# 6.4     7
# 5.8     7
# 5.5     7
# 5.4     6
# 6.1     6
# 5.6     6
# 6.0     6
# 4.9     6
# 4.8     5
# 6.5     5
# 6.2     4
# 5.2     4
# 4.6     4
# 7.7     4
# 6.9     4
# 7.2     3
# 5.9     3
# 4.4     3
# 6.8     3
# 4.7     2
# 6.6     2
# 7.4     1
# 7.6     1
# 7.3     1
# 4.3     1
# 7.1     1
# 7.0     1
# 5.3     1
# 4.5     1
# 7.9     1
# dtype: int64

# %%
df.value_counts("PetalLengthCm")
# Out:
# PetalLengthCm
# 1.5    14
# 1.4    12
# 4.5     8
# 5.1     8
# 1.3     7
# 1.6     7
# 5.6     6
# 4.0     5
# 4.9     5
# 4.7     5
# 5.0     4
# 4.8     4
# 4.4     4
# 4.2     4
# 1.7     4
# 5.8     3
# 4.1     3
# 5.7     3
# 5.5     3
# 6.1     3
# 4.6     3
# 3.9     3
# 6.7     2
# 1.2     2
# 5.4     2
# 5.3     2
# 5.2     2
# 5.9     2
# 1.9     2
# 3.3     2
# 3.5     2
# 4.3     2
# 6.0     2
# 6.6     1
# 6.4     1
# 6.3     1
# 1.0     1
# 1.1     1
# 3.8     1
# 3.7     1
# 3.6     1
# 3.0     1
# 6.9     1
# dtype: int64

# %%
df.value_counts("SepalWidthCm")
# Out:
# SepalWidthCm
# 3.0    26
# 2.8    14
# 3.2    13
# 3.4    12
# 3.1    12
# 2.9    10
# 2.7     9
# 2.5     8
# 3.3     6
# 3.5     6
# 3.8     6
# 2.6     5
# 2.3     4
# 2.4     3
# 2.2     3
# 3.6     3
# 3.7     3
# 3.9     2
# 4.1     1
# 4.2     1
# 2.0     1
# 4.0     1
# 4.4     1
# dtype: int64

# %%
df.value_counts("PetalWidthCm")
# Out:
# PetalWidthCm
# 0.2    28
# 1.3    13
# 1.5    12
# 1.8    12
# 2.3     8
# 1.4     8
# 0.3     7
# 0.4     7
# 1.0     7
# 2.1     6
# 2.0     6
# 0.1     6
# 1.2     5
# 1.9     5
# 1.6     4
# 1.1     3
# 2.2     3
# 2.4     3
# 2.5     3
# 1.7     2
# 0.6     1
# 0.5     1
# dtype: int64

# %%
df.value_counts("Species")
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
data.corr(method='pearson')
# Out:
# C:\Users\SHASANK\AppData\Local\Temp\ipykernel_8472\2721894934.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr(method='pearson')
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.624413     -0.654654       0.969909
# SepalLengthCm  0.624413       1.000000     -0.999226       0.795795
# SepalWidthCm  -0.654654      -0.999226      1.000000      -0.818999
# PetalLengthCm  0.969909       0.795795     -0.818999       1.000000
# PetalWidthCm   0.999685       0.643817     -0.673417       0.975713
#
#                PetalWidthCm
# Id                 0.999685
# SepalLengthCm      0.643817
# SepalWidthCm      -0.673417
# PetalLengthCm      0.975713
# PetalWidthCm       1.000000

# %% [markdown]
# # visualizing the data

# %%
sns.countplot(x='Species',data=df)
plt.show()

# %%
df['SepalLengthCm'].hist()
# Out:
# <Axes: >

# %%
df['SepalWidthCm'].hist()
# Out:
# <Axes: >

# %%
df['PetalLengthCm'].hist()
# Out:
# <Axes: >

# %%
df['PetalWidthCm'].hist()
# Out:
# <Axes: >

# %%
sns.pairplot(df, hue='Species',height=2)

# %%
sns.heatmap(df.corr(method='pearson').drop(['Id'], axis=1).drop(['Id'], axis=0),annot=True,cmap='coolwarm');
# Out:
# C:\Users\SHASANK\AppData\Local\Temp\ipykernel_8472\3854522247.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(method='pearson').drop(['Id'], axis=1).drop(['Id'], axis=0),annot=True,cmap='coolwarm');

# %% [markdown]
# # Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Species']=le.fit_transform(df['Species'])

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %% [markdown]
# # Splitting Iris data set into train_set and test_set

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop(columns=['Species'])
Y=df['Species']

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.30)

# %% [markdown]
# # Training Data set

# %%
#Let's import some models and train the data set using the differnt Machine Learning Algorthims

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
#model Training
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("Accuracy:",model.score(x_test,y_test)*100)
# Out:
# Accuracy: 96.08570291454261

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\SHASANK\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print("Accuracy:",model.score(x_test,y_test)*100)
# Out:
# Accuracy: 100.0
